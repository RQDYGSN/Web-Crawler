# %% [markdown]
# Scrapy不是一个简单的库，而是专业的爬虫框架结构

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Engine：控制数据流，根据条件触发事件；
# 2. Downloader：根据请求下载网页；
# 3. Scheduler：对所有爬取请求进行调度管理；
# 4. Spider（用户编写）：解析Downloader返回的响应，产生爬取项和额外爬取请求。
# 5. Item Pipelines（用户编写）：以流水线方式处理Spider的爬取项。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #其中startproject，genspider，crawl是最常用的。
