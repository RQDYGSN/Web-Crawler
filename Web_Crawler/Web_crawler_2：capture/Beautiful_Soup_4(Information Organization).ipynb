# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #国际公认的三种信息标记形式：XML，JSON，YAML

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# YAML与python一致的是使用前空格表达所属关系。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #XML：最早的通用信息标记语言，可扩展性好，但繁琐；多用于因特网信息交互。
# #JSON：信息有类型，适用于程序处理；多用于移动应用云端和节点的信息通信，但无注释。
# #YAML：信息无类型，文本信息比例最高，可读性好；多用于各类系统的配置文件。
