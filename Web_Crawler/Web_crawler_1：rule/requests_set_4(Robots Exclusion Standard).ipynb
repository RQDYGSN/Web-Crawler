# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #Robots协议都是显示在网页的根目录下，在其后加上"/robots.txt"查看。
# #User-agent
# #Disallow

# %%
...
Disallow: /?*
Disallow: /pop/*.html
...
#不允许访问以‘？’开头的路径
#不允许访问以‘pop’开头，以‘.html’结尾的路径

# %% [markdown]
# # Robots基本框架

# %%
User-agent: *
Disallow: /

# %% [markdown]
# #第一行表示爬虫类型，如果是‘*’，则表示所有爬虫
# #第二行是对第一行列下的规定，说明不允许以什么形式进行爬取信息。‘/’表示禁止所有行为
